# %%
import numpy as np

# %%
import numpy as np

def f(theta):
    # Fixed constants
    L1 = 2
    L2 = np.sqrt(2)
    L3 = np.sqrt(2)
    gamma = np.pi / 2

    # Known strut lengths
    p1 = np.sqrt(5)
    p2 = np.sqrt(5)
    p3 = np.sqrt(5)

    # Base triangle coordinates adjusted for consistency
    # Base point 1 at (0, 0)
    # Base point 2 at (L1, 0)
    x1 = L1  # x-coordinate of base point 2
    # Base point 3 at (L1/2, L1 * sin(π/3)) for an equilateral triangle
    x2 = L1 / 2
    y2 = L1 * np.sin(np.pi / 3)  # sin(60°) = √3 / 2

    # Compute A2 and B2
    A2 = L3 * np.cos(theta) - x1
    B2 = L3 * np.sin(theta)

    # Compute A3 and B3
    A3 = L2 * np.cos(theta + gamma) - x2
    B3 = L2 * np.sin(theta + gamma) - y2

    # Compute intermediate terms
    term1 = p2**2 - p1**2 - A2**2 - B2**2
    term2 = p3**2 - p1**2 - A3**2 - B3**2

    # Compute N1, N2, and D
    N1 = B3 * term1 - B2 * term2
    N2 = -A3 * term1 + A2 * term2
    D = 2 * (A2 * B3 - B2 * A3)

    # Compute the output
    out = N1**2 + N2**2 - (p1 * D)**2

    return out

# Test the function at theta = -pi/4 and theta = pi/4
def test_f():
    theta_values = [-np.pi / 4, np.pi / 4]
    for theta in theta_values:
        result = f(theta)
        print(f"f({theta}) = {result}")

test_f()
# Out:
# f(-0.7853981633974483) = -9.56921938165305
# f(0.7853981633974483) = -112.99484522385714

# %%
import matplotlib.pyplot as plt

def plot_f():
    theta_vals = np.linspace(-np.pi, np.pi, 1000)
    f_vals = np.array([f(theta) for theta in theta_vals])

    plt.plot(theta_vals, f_vals)
    plt.axhline(0, color='black', linestyle='--')
    plt.xlabel('Theta (radians)')
    plt.ylabel('f(Theta)')
    plt.title('Plot of f(Theta) vs. Theta')
    plt.grid(True)
    plt.show()

plot_f()
